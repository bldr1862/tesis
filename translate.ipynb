# %%
import utils
import params
from tqdm import tqdm
import time
import requests
import json

# %%
captions = utils.readCaptions(params.TRAIN_CAPTIONS_PATH)

# %%
captions.__len__()
# Out:
# 414113

# %%
def translate(TEXT_LIST):
    str_=''
    for TEXT in TEXT_LIST:
        str_ = str_ + 'q='+TEXT+'&'
    API_KEY = 'AIzaSyA4y6FVWWD-mgyAoqtDuEMcqISVC1WYSfo'
    URL = 'https://translation.googleapis.com/language/translate/v2?{}target=es&key={}'
    TEXT = TEXT.strip().replace(' ','+')
    response = requests.get(URL.format(str_, API_KEY))
    translations = []
    try:
        for translation in json.loads(response.content)['data']['translations']:
            translations.append(translation['translatedText'])
    except:
        time.sleep(10)
        translate(TEXT_LIST)
    return translations

# %%
translate(['Hello I am fine', ' Really?'])
# Out:
# ['Hola estoy bien', 'De Verdad?']

# %%
spanish_captions = []

# %%
BATCH = 50

# %%
spanish = []
for batch in tqdm(utils.chunks(captions,BATCH)):
    ids = []
    en_captions = []
    for element in batch:
        ids.append(element['image_id'])
        en_captions.append(element['caption'])
        
    es_captions = translate(en_captions)
    for id_, cap in zip(ids, es_captions):
        spanish.append({'caption':cap,'image_id':id_})
# Out:
# 718it [33:16,  2.78s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\bldr1\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Users\bldr1\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# C:\Users\bldr1\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ...

# %%
np.save('DATASETS/spanish.npy',spanish)

# %%
spanish.__len__()
# Out:
# 35050

# %%
import xlsxwriter

# %%
for counter in range(5):
    workbook = xlsxwriter.Workbook('EXCELS/translation_{}.xlsx'.format(counter))
    worksheet = workbook.add_worksheet()
    i = 1
    for element in tqdm(captions[counter*100000:(counter+1)*100000]):
        cap = element['caption']
        image_id = element['image_id']
        worksheet.write('A{}'.format(i),image_id)
        worksheet.write('B{}'.format(i),cap)
        i = i+1
    workbook.close()
# Out:
# ...
# 100%|██████████| 14113/14113 [00:01<00:00, 12496.11it/s]

# %%
import pandas as pd

# %%
import utils
import params
from tqdm import tqdm
import time
import requests
import json
import xlsxwriter

# %%
dfs = []
for counter in range(5):
    df = pd.read_excel(r'C:\Users\bldr1\Downloads\translation_{}.xlsx'.format(counter), header=None)
    df.columns = ['image_id','english','gt','spanish']
    dfs.append(df)

# %%
df.head()
# Out:
#    image_id                                            english  \
# 0    155299  A refrigerator is positioned in a dining room ...
# 1    539589  A man sitting at a table surrounded by glasses...
# 2     66669     A little girl sitting next to two teddy bears.
# 3    243504  A small rodent sitting between a group of batt...
# 4    485598     Big Ben and the Palace of Westminster at night
#
#                                                   gt  \
# 0  Un refrigerador se coloca en un comedor hacien...
# 1  Un hombre sentado en una mesa rodeada de vasos...
# 2  Una niña que se sienta al lado de dos osos de ...
# 3  Un pequeño roedor sentado entre un grupo de ba...
# 4    Big Ben y el palacio de Westminster en la noche
#
#                                              spanish
# 0  Un refrigerador se coloca en un comedor hacien...
# 1  Un hombre sentado en una mesa rodeada de vasos...
# 2  Una niña que se sienta al lado de dos osos de ...
# ...

# %%
df = pd.concat(dfs)

# %%
df.shape
# Out:
# (414113, 4)

# %%
df.head()
# Out:
#    image_id                                            english  \
# 0    318556     A very clean and well decorated empty bathroom
# 1    116100  A panoramic view of a kitchen and all of its a...
# 2    318556  A blue and white bathroom with butterfly theme...
# 3    116100     A panoramic photo of a kitchen and dining room
# 4    379340  A graffiti-ed stop sign across the street from...
#
#                                                   gt  \
# 0  Un cuarto de baño muy limpio y bien decorado v...
# 1  Una vista panorámica de una cocina y todos sus...
# 2  Un cuarto de baño azul y blanco con azulejos d...
# 3        Una foto panorámica de una cocina y comedor
# 4  Una señal de stop de graffiti-ed en la calle d...
#
#                                              spanish
# 0  Un cuarto de baño muy limpio y bien decorado v...
# 1  Una vista panorámica de una cocina y todos sus...
# 2  Un cuarto de baño azul y blanco con azulejos d...
# ...

# %%
captions = []
for id, cap in zip(df['image_id'], df['spanish']):
    dt = {'image_id':id,'caption':cap}
    captions.append(dt)

# %%
captions
# Out:
# [{'caption': 'Un cuarto de baño muy limpio y bien decorado vacío',
#   'image_id': 318556},
#  {'caption': 'Una vista panorámica de una cocina y todos sus aparatos.',
#   'image_id': 116100},
#  {'caption': 'Un cuarto de baño azul y blanco con azulejos de la pared temáticos de la mariposa.',
#   'image_id': 318556},
#  {'caption': 'Una foto panorámica de una cocina y comedor',
#   'image_id': 116100},
#  {'caption': 'Una señal de stop de graffiti-ed en la calle de un coche rojo',
#   'image_id': 379340},
#  {'caption': 'Una señal de stop objeto de vandalismo y un escarabajo rojo en la carretera',
#   'image_id': 379340},
#  {'caption': 'Un cuarto de baño con una frontera de las mariposas y la pintura azul en las paredes por encima de ella.',
#   'image_id': 318556},
#  {'caption': 'Un ángulo de vista de un cuarto de baño muy bien decorado.',
#   'image_id': 318556},
#  {'caption': 'Las dos personas están caminando por la playa.',
#   'image_id': 134754},
# ...

# %%
np.save(r'C:\Users\bldr1\Desktop\TESIS\DATASETS\spanish_train.npy',captions)

# %%
import numpy as np
